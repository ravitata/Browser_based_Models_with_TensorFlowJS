# %% [markdown]
# <a href="https://colab.research.google.com/github/ravitata/Browser_based_Models_with_TensorFlowJS/blob/main/Linear_to_JavaScript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 71kB 6.0MB/s
# ...
#      |████████████████████████████████| 112kB 10.9MB/s
# ...
#   Found existing installation: tensorflow-hub 0.10.0
#     Uninstalling tensorflow-hub-0.10.0:
#       Successfully uninstalled tensorflow-hub-0.10.0
# ...

# %%
import numpy as np
import tensorflow as tf

print('\u2022 Using TensorFlow Version:', tf.__version__)
# Out:
# • Using TensorFlow Version: 2.3.0

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units=1, input_shape=[1])  
])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 53.0360
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 42.1317
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 33.5444
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 26.7801
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 21.4503
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 17.2493
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 13.9365
# Epoch 8/500
# 1/1 [==============================] - 0s 875us/step - loss: 11.3226
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2588
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6278
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3376
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3157
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.97614]]

# %%
import time
saved_model_path = "./{}.h5".format(int(time.time()))

model.save(saved_model_path)

# %%
# !tensorflowjs_converter --input_format=keras {saved_model_path} ./
# Out:
# 2020-11-25 03:29:50.715126: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
